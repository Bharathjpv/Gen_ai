# %%
job_position = """Senior Data Scientist (Machine Learning)

Company: TechNova Solutions
Location: San Francisco, CA

Job Description:

TechNova Solutions is seeking a Senior Data Scientist specializing in Machine Learning to join our dynamic analytics team. The ideal candidate will have a strong background in developing and deploying machine learning models, working with large datasets, and translating complex data into actionable insights.

Responsibilities:

Develop and implement advanced machine learning algorithms and models.
Analyze large, complex datasets to extract meaningful patterns and insights.
Collaborate with cross-functional teams to integrate predictive models into products.
Stay updated with the latest advancements in machine learning and data science.
Mentor junior data scientists and provide technical guidance.
Qualifications:

Master’s or Ph.D. in Data Science, Computer Science, Statistics, or a related field.
5+ years of experience in data science and machine learning.
Proficient in Python, R, and SQL.
Experience with deep learning frameworks (e.g., TensorFlow, PyTorch).
Strong problem-solving skills and attention to detail.
Candidate CVs
"""

# %%
job_1 = """
CV 1: Relevant
Name: Dr. Emily Carter
Contact Information:

Email: emily.carter@example.com
Phone: (555) 123-4567
Summary:

Senior Data Scientist with over 8 years of experience in machine learning and predictive analytics. Expertise in developing advanced algorithms and deploying scalable models in production environments.

Education:

Ph.D. in Computer Science, Stanford University (2014)
B.S. in Mathematics, University of California, Berkeley (2010)
Experience:

Senior Data Scientist, InnovateAI Labs (2016 – Present)
Led a team in developing machine learning models for natural language processing applications.
Implemented deep learning algorithms that improved prediction accuracy by 25%.
Collaborated with cross-functional teams to integrate models into cloud-based platforms.
Data Scientist, DataWave Analytics (2014 – 2016)
Developed predictive models for customer segmentation and churn analysis.
Analyzed large datasets using Hadoop and Spark frameworks.
Skills:

Programming Languages: Python, R, SQL
Machine Learning: TensorFlow, Keras, Scikit-Learn
Big Data Technologies: Hadoop, Spark
Data Visualization: Tableau, Matplotlib
"""

# %%
job_2 = """
CV 2: Relevant
Name: Michael Rodriguez
Contact Information:

Email: michael.rodriguez@example.com
Phone: (555) 234-5678
Summary:

Data Scientist with a strong background in machine learning and statistical modeling. Skilled in handling large datasets and translating data into actionable business insights.

Education:

M.S. in Data Science, Carnegie Mellon University (2013)
B.S. in Computer Science, University of Michigan (2011)
Experience:

Senior Data Scientist, Alpha Analytics (2017 – Present)
Developed machine learning models to optimize marketing strategies.
Reduced customer acquisition cost by 15% through predictive modeling.
Data Scientist, TechInsights (2013 – 2017)
Analyzed user behavior data to improve product features.
Implemented A/B testing frameworks to evaluate product changes.
Skills:

Programming Languages: Python, Java, SQL
Machine Learning: Scikit-Learn, XGBoost
Data Visualization: Seaborn, Plotly
Databases: MySQL, MongoDB
"""

# %%
job_3 = """
CV 3: Relevant
Name: Sarah Nguyen
Contact Information:

Email: sarah.nguyen@example.com
Phone: (555) 345-6789
Summary:

Data Scientist specializing in machine learning with 6 years of experience. Passionate about leveraging data to drive business solutions and improve product performance.

Education:

M.S. in Statistics, University of Washington (2014)
B.S. in Applied Mathematics, University of Texas at Austin (2012)
Experience:

Data Scientist, QuantumTech (2016 – Present)
Designed and implemented machine learning algorithms for financial forecasting.
Improved model efficiency by 20% through algorithm optimization.
Junior Data Scientist, DataCore Solutions (2014 – 2016)
Assisted in developing predictive models for supply chain optimization.
Conducted data cleaning and preprocessing on large datasets.
Skills:

Programming Languages: Python, R
Machine Learning Frameworks: PyTorch, Scikit-Learn
Statistical Analysis: SAS, SPSS
Cloud Platforms: AWS, Azure
"""

# %%
job_4 = """
CV 4: Not Relevant
Name: David Thompson
Contact Information:

Email: david.thompson@example.com
Phone: (555) 456-7890
Summary:

Creative Graphic Designer with over 8 years of experience in visual design and branding. Proficient in Adobe Creative Suite and passionate about creating compelling visuals.

Education:

B.F.A. in Graphic Design, Rhode Island School of Design (2012)
Experience:

Senior Graphic Designer, CreativeWorks Agency (2015 – Present)
Led design projects for clients in various industries.
Created branding materials that increased client engagement by 30%.
Graphic Designer, Visual Innovations (2012 – 2015)
Designed marketing collateral, including brochures, logos, and websites.
Collaborated with the marketing team to develop cohesive brand strategies.
Skills:

Design Software: Adobe Photoshop, Illustrator, InDesign
Web Design: HTML, CSS
Specialties: Branding and Identity, Typography
"""

# %%
job_5 = """
CV 5: Not Relevant
Name: Jessica Miller
Contact Information:

Email: jessica.miller@example.com
Phone: (555) 567-8901
Summary:

Experienced Sales Manager with a strong track record in driving sales growth and building high-performing teams. Excellent communication and leadership skills.

Education:

B.A. in Business Administration, University of Southern California (2010)
Experience:

Sales Manager, Global Enterprises (2015 – Present)
Managed a sales team of 15 members, achieving a 20% increase in annual revenue.
Developed sales strategies that expanded customer base by 25%.
Sales Representative, Market Leaders Inc. (2010 – 2015)
Consistently exceeded sales targets and received the 'Top Salesperson' award in 2013.
Skills:

Sales Strategy and Planning
Team Leadership and Development
CRM Software: Salesforce, Zoho
Negotiation and Relationship Building
"""

# %%
from json import load
import os
import dotenv

dotenv.load_dotenv()

# Setting environment variables

if "LLM_API_KEY" not in os.environ:
    os.environ["LLM_API_KEY"] = "YOUR KEY"

# "neo4j" or "networkx"
os.environ["GRAPH_DATABASE_PROVIDER"] = "kuzu"
# Not needed if using kuzu
# os.environ["GRAPH_DATABASE_URL"]=""
# os.environ["GRAPH_DATABASE_USERNAME"]=""
# os.environ["GRAPH_DATABASE_PASSWORD"]=""

# "pgvector", "qdrant", "weaviate" or "lancedb"
os.environ["VECTOR_DB_PROVIDER"] = "lancedb"
# Not needed if using "lancedb" or "pgvector"
# os.environ["VECTOR_DB_URL"]=""
# os.environ["VECTOR_DB_KEY"]=""

# Relational Database provider "sqlite" or "postgres"
os.environ["DB_PROVIDER"] = "sqlite"

# Database name
os.environ["DB_NAME"] = "cognee_db"

# Postgres specific parameters (Only if Postgres or PGVector is used)
# os.environ["DB_HOST"]="127.0.0.1"
# os.environ["DB_PORT"]="5432"
# os.environ["DB_USERNAME"]="cognee"
# os.environ["DB_PASSWORD"]="cognee"

# %%
# Reset the cognee system with the following command:

import cognee

await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)
print(cognee.__version__)
# Out:
# 2026-01-23T12:14:14.136613 [warning  ] From version 0.5.0 onwards, Cognee will run with multi-user access control mode set to on by default. Data isolation between different users and datasets will be enforced and data created before multi-user access control mode was turned on won't be accessible by default. To disable multi-user access control mode and regain access to old data set the environment variable ENABLE_BACKEND_ACCESS_CONTROL to false before starting Cognee. For more information, please refer to the Cognee documentation. [cognee.shared.logging_utils]
#
# 2026-01-23T12:14:14.137227 [info     ] Log file created at: /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/logs/2026-01-23_17-44-13.log [cognee.shared.logging_utils] log_file=/Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/logs/2026-01-23_17-44-13.log
#
# 2026-01-23T12:14:14.137623 [info     ] Logging initialized            [cognee.shared.logging_utils] cognee_version=0.5.1 database_path=/Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/cognee/.cognee_system/databases graph_database_name= os_info='Darwin 25.2.0 (Darwin Kernel Version 25.2.0: Tue Nov 18 21:09:40 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6000)' python_version=3.13.5 relational_config=cognee_db structlog_version=25.5.0 vector_config=lancedb
#
# 2026-01-23T12:14:14.138143 [info     ] Database storage: /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/cognee/.cognee_system/databases [cognee.shared.logging_utils]
#
# 2026-01-23T12:14:14.483299 [info     ] Loaded JSON extension          [cognee.shared.logging_utils]
#
# 2026-01-23T12:14:14.506017 [info     ] Deleted Kuzu database files at /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/cognee/.cognee_system/databases/cognee_graph_kuzu [cognee.shared.logging_utils]
#
# 2026-01-23T12:14:17.206438 [info     ] Database deleted successfully. [cognee.shared.logging_utils]
#
# Storage manager absolute path: /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/.venv/lib/python3.13/site-packages/cognee/.cognee_cache
#
# Deleting cache...
#
# ✓ Cache deleted successfully!
# 0.5.1

# %%
import cognee

await cognee.add([job_1, job_2, job_3, job_4, job_5, job_position], "example")
# Out:
# User 0b926174-ad65-4ac6-9030-b007aa129322 has registered.
# 2026-01-23T12:14:25.114245 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:25.558836 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:25.884400 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:26.221970 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:26.606551 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:26.912987 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:27.240659 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:27.538005 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:27.838763 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:28.245128 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:28.576915 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:28.979113 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:29.316805 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:29.629566 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:30.030103 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:30.344335 [info     ] Pipeline run started: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:30.706731 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:31.077400 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:31.468388 [info     ] Registered loader: pypdf_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.468915 [info     ] Registered loader: text_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.469384 [info     ] Registered loader: image_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.469845 [info     ] Registered loader: audio_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.470216 [info     ] Registered loader: csv_loader  [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.470725 [info     ] Registered loader: unstructured_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.471083 [info     ] Registered loader: advanced_pdf_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-01-23T12:14:31.520784 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:31.914123 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:32.222648 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:32.558499 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:32.954987 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:33.284148 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:33.604109 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:34.001396 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:34.334164 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:34.647356 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:35.067205 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:35.389078 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:35.721317 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:36.090113 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:36.410949 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:14:36.851640 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2026-01-23T12:14:37.158352 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2026-01-23T12:14:37.504748 [info     ] Pipeline run completed: `aabbc0e3-599a-5b55-b3bd-01e26773c1da` [run_tasks_with_telemetry()]
# PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=[{'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('81c7d9a5-f0f8-5735-a2d8-1ea381ffcd18')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('0910b840-44be-5070-a052-50b4d3924a08')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('55f3ccf4-44d5-5f8f-b89a-29e6eed6ee9e')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('88704677-4fd9-54e6-863c-a9718ebeae7b')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('d3bc011c-984d-5439-b271-f61e2d6aa94c')}, {'run_info': PipelineRunCompleted(status='PipelineRunCompleted', pipeline_run_id=UUID('9cdca79b-9822-51e5-b07f-a9b3a51e1e98'), dataset_id=UUID('a0c12278-fe16-5799-a21f-66be45593150'), dataset_name='example', payload=None, data_ingestion_info=None), 'data_id': UUID('83c6899d-68f2-5642-9309-43fb55bd7a13')}])

# %%
from cognee.shared.data_models import KnowledgeGraph
from cognee.modules.data.models import Dataset, Data
from cognee.modules.data.methods.get_dataset_data import get_dataset_data
from cognee.modules.cognify.config import get_cognify_config
from cognee.modules.pipelines.tasks.task import Task
from cognee.modules.pipelines import run_tasks
from cognee.modules.users.models import User
from cognee.tasks.documents import (
    classify_documents,
    extract_chunks_from_documents,
)
from cognee.infrastructure.llm import get_max_chunk_tokens
from cognee.tasks.graph import extract_graph_from_data
from cognee.tasks.storage import add_data_points
from cognee.tasks.summarization import summarize_text


async def run_cognify_pipeline(dataset: Dataset, user: User = None):
    data_documents: list[Data] = await get_dataset_data(dataset_id=dataset.id)

    try:
        cognee_config = get_cognify_config()

        tasks = [
            Task(classify_documents),
            Task(
                extract_chunks_from_documents, max_chunk_size=get_max_chunk_tokens()
            ),  # Extract text chunks based on the document type.
            Task(
                extract_graph_from_data, graph_model=KnowledgeGraph,
                task_config={"batch_size": 10}
            ),  # Generate knowledge graphs from the document chunks.
            Task(
                summarize_text,
                summarization_model=cognee_config.summarization_model,
                task_config={"batch_size": 10},
            ),
            Task(add_data_points, task_config={"batch_size": 10}),
        ]

        pipeline_run = run_tasks(tasks, dataset.id, data_documents, user, "cognify_pipeline", context={"dataset": dataset})
        pipeline_run_status = None

        async for run_status in pipeline_run:
            pipeline_run_status = run_status

    except Exception as error:
        raise error

# %%
from cognee.modules.users.methods import get_default_user
from cognee.modules.data.methods import get_datasets_by_name
from cognee.modules.users.methods import get_user

default_user = await get_default_user()

user = await get_user(default_user.id)

datasets = await get_datasets_by_name(["example"], user.id)

await run_cognify_pipeline(datasets[0], user)
# Out:
# 2026-01-23T12:15:09.419479 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:09.733362 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:10.150873 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:10.836774 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:11.217300 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:11.524985 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:11.854325 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:12.247393 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:12.604983 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:12.922903 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:13.327252 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:13.640165 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:13.967138 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:14.373781 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:14.726222 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:15.121529 [info     ] Pipeline run started: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:15:15.435982 [info     ] Coroutine task started: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:15:15.758545 [info     ] Async Generator task started: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:15:16.087827 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:15:16.613401 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:15:16.988473 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:15:17.315514 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:15:17.650503 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:15:18.036630 [info     ] Coroutine task started: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:07.051860 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:07.054720 [info     ] Reconnecting to Kuzu database... [cognee.shared.logging_utils]
#
# 2026-01-23T12:16:07.096432 [info     ] Loaded JSON extension          [cognee.shared.logging_utils]
#
# 2026-01-23T12:16:07.127343 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.127905 [info     ] No close match found for 'jessica miller' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.128422 [info     ] No close match found for 'email' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.128760 [info     ] No close match found for 'jessica.miller@example.com' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.129161 [info     ] No close match found for 'phone' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.129682 [info     ] No close match found for '(555) 567-8901' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.130092 [info     ] No close match found for 'degree' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.130436 [info     ] No close match found for 'b.a. in business administration' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.130759 [info     ] No close match found for 'organization' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.131046 [info     ] No close match found for 'university of southern california' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.131324 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.131624 [info     ] No close match found for '2010' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.131935 [info     ] No close match found for 'job' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.132346 [info     ] No close match found for 'sales manager, global enterprises' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.132710 [info     ] No close match found for 'global enterprises' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.132983 [info     ] No close match found for '2015' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.133262 [info     ] No close match found for 'present' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.133546 [info     ] No close match found for 'sales representative, market leaders inc.' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.133847 [info     ] No close match found for 'market leaders inc.' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.134123 [info     ] No close match found for '2013' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.134386 [info     ] No close match found for 'award' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.134631 [info     ] No close match found for 'top salesperson award (2013)' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.152881 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.153445 [info     ] No close match found for 'sales strategy and planning' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.153880 [info     ] No close match found for 'team leadership and development' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.154301 [info     ] No close match found for 'software' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.154625 [info     ] No close match found for 'salesforce' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.155258 [info     ] No close match found for 'zoho' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.155750 [info     ] No close match found for 'negotiation and relationship building' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.296037 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:07.299540 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.300138 [info     ] No close match found for 'david thompson' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.300706 [info     ] No close match found for 'email' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.301187 [info     ] No close match found for 'david.thompson@example.com' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.301581 [info     ] No close match found for 'phone' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.301987 [info     ] No close match found for '(555) 456-7890' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.302396 [info     ] No close match found for 'organization' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.302798 [info     ] No close match found for 'rhode island school of design' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.303171 [info     ] No close match found for 'degree' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.303587 [info     ] No close match found for 'b.f.a. in graphic design' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.303987 [info     ] No close match found for 'creativeworks agency' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.304295 [info     ] No close match found for 'visual innovations' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.304771 [info     ] No close match found for 'position' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.305177 [info     ] No close match found for 'senior graphic designer' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.305697 [info     ] No close match found for 'graphic designer' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.306810 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.307281 [info     ] No close match found for '2012' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.307661 [info     ] No close match found for '2015' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.307946 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:07.308432 [info     ] No close match found for 'adobe photoshop' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.308902 [info     ] No close match found for 'adobe illustrator' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.309203 [info     ] No close match found for 'adobe indesign' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.310235 [info     ] No close match found for 'html' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.310966 [info     ] No close match found for 'css' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.311440 [info     ] No close match found for 'branding and identity' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:07.311694 [info     ] No close match found for 'typography' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.407297 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:12.410778 [info     ] No close match found for 'company' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.411315 [info     ] No close match found for 'technova solutions' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.411752 [info     ] No close match found for 'job' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.412106 [info     ] No close match found for 'senior data scientist (machine learning)' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.412488 [info     ] No close match found for 'location' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.412861 [info     ] No close match found for 'san francisco, ca' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.413211 [info     ] No close match found for 'team' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.413530 [info     ] No close match found for 'analytics team' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.413941 [info     ] No close match found for 'responsibility' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.414430 [info     ] No close match found for 'develop and implement advanced machine learning algorithms and models' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.414809 [info     ] No close match found for 'analyze large complex datasets to extract meaningful patterns and insights' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.415090 [info     ] No close match found for 'collaborate with cross-functional teams to integrate predictive models into products' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.415435 [info     ] No close match found for 'stay updated with the latest advancements in machine learning and data science' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.415763 [info     ] No close match found for 'mentor junior data scientists and provide technical guidance' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.416109 [info     ] No close match found for 'qualification' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.416519 [info     ] No close match found for 'masters or ph.d. in data science computer science statistics or related field' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.416990 [info     ] No close match found for 'experience' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.417434 [info     ] No close match found for '5+ years experience in data science and machine learning' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.417771 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.418225 [info     ] No close match found for 'python' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.418720 [info     ] No close match found for 'r' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.419082 [info     ] No close match found for 'sql' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.419383 [info     ] No close match found for 'deep learning frameworks (tensorflow pytorch)' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.419753 [info     ] No close match found for 'tensorflow' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.420240 [info     ] No close match found for 'pytorch' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.420583 [info     ] No close match found for 'machine learning' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.420980 [info     ] No close match found for 'data science' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.421380 [info     ] No close match found for 'problem-solving skills' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.421830 [info     ] No close match found for 'attention to detail' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.422286 [info     ] No close match found for 'role' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:12.422651 [info     ] No close match found for 'junior data scientists' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:12.660609 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:14.701465 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:18.899843 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:23.364075 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:23.367550 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.367944 [info     ] No close match found for 'sarah nguyen' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.368245 [info     ] No close match found for 'organization' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.368780 [info     ] No close match found for 'quantumtech' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.369217 [info     ] No close match found for 'datacore solutions' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.369532 [info     ] No close match found for 'university of washington' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.369854 [info     ] No close match found for 'university of texas at austin' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.370242 [info     ] No close match found for 'degree' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.370583 [info     ] No close match found for 'm.s. in statistics' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.370961 [info     ] No close match found for 'b.s. in applied mathematics' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.371228 [info     ] No close match found for 'position' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.371616 [info     ] No close match found for 'data scientist (quantumtech)' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.371817 [info     ] No close match found for 'junior data scientist (datacore solutions)' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.372201 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.372483 [info     ] No close match found for '2016' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.372948 [info     ] No close match found for '2014' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.373279 [info     ] No close match found for '2012' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.373651 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.374203 [info     ] No close match found for 'python' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.374485 [info     ] No close match found for 'r' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.374824 [info     ] No close match found for 'technology' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:23.375076 [info     ] No close match found for 'pytorch' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.375296 [info     ] No close match found for 'scikit-learn' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.375497 [info     ] No close match found for 'sas' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.375927 [info     ] No close match found for 'spss' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.376221 [info     ] No close match found for 'aws' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.376589 [info     ] No close match found for 'azure' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.376938 [info     ] No close match found for 'financial forecasting' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:23.460067 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:24.220233 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:26.074865 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:26.456814 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:26.593256 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.593659 [info     ] No close match found for 'michael rodriguez' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.594016 [info     ] No close match found for 'email' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.594406 [info     ] No close match found for 'michael.rodriguez@example.com' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.594630 [info     ] No close match found for 'phonenumber' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.594887 [info     ] No close match found for '(555) 234-5678' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.595151 [info     ] No close match found for 'degree' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.595682 [info     ] No close match found for 'm.s. in data science' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.596077 [info     ] No close match found for 'b.s. in computer science' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.596424 [info     ] No close match found for 'organization' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.596815 [info     ] No close match found for 'carnegie mellon university' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.597472 [info     ] No close match found for 'university of michigan' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.597977 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.598457 [info     ] No close match found for '2013' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.598816 [info     ] No close match found for '2011' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.599209 [info     ] No close match found for '2017' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.599523 [info     ] No close match found for 'jobtitle' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.599814 [info     ] No close match found for 'senior data scientist' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.600120 [info     ] No close match found for 'data scientist' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.600493 [info     ] No close match found for 'alpha analytics' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.600763 [info     ] No close match found for 'techinsights' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.601090 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.601321 [info     ] No close match found for 'python' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.601703 [info     ] No close match found for 'java' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.602090 [info     ] No close match found for 'sql' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.602433 [info     ] No close match found for 'scikit-learn' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.602778 [info     ] No close match found for 'xgboost' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.603304 [info     ] No close match found for 'seaborn' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.603788 [info     ] No close match found for 'plotly' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.604119 [info     ] No close match found for 'mysql' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.604541 [info     ] No close match found for 'mongodb' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.604885 [info     ] No close match found for 'machine learning' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.605494 [info     ] No close match found for 'statistical modeling' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.605843 [info     ] No close match found for 'a/b testing' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.606355 [info     ] No close match found for 'achievement' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.606854 [info     ] No close match found for 'reduced customer acquisition cost by 15%' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.607393 [info     ] No close match found for 'project' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:26.607772 [info     ] No close match found for 'developed machine learning models to optimize marketing strategies' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:26.663106 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:26.979567 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:27.294475 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:27.613525 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:16:27.997886 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:16:28.307936 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:16:28.834808 [info     ] No ontology file provided. No owl ontology will be attached to the graph. [OntologyAdapter]
#
# 2026-01-23T12:16:28.841428 [info     ] No close match found for 'person' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.841855 [info     ] No close match found for 'emily carter' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.842351 [info     ] No close match found for 'degree' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.842757 [info     ] No close match found for 'ph.d. in computer science' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.843056 [info     ] No close match found for 'institution' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.843399 [info     ] No close match found for 'stanford university' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.843843 [info     ] No close match found for 'date' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.844097 [info     ] No close match found for '2014' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.844479 [info     ] No close match found for 'b.s. in mathematics' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.844822 [info     ] No close match found for 'university of california, berkeley' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.845095 [info     ] No close match found for '2010' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.845337 [info     ] No close match found for 'role' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.845596 [info     ] No close match found for 'senior data scientist' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.845898 [info     ] No close match found for 'organization' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.846159 [info     ] No close match found for 'innovateai labs' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.846398 [info     ] No close match found for '2016' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.846641 [info     ] No close match found for 'present' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.846905 [info     ] No close match found for 'data scientist' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.847139 [info     ] No close match found for 'datawave analytics' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.847538 [info     ] No close match found for 'skill' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.847902 [info     ] No close match found for 'python' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.848179 [info     ] No close match found for 'r' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.848583 [info     ] No close match found for 'sql' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.848975 [info     ] No close match found for 'technology' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.849302 [info     ] No close match found for 'tensorflow' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.849720 [info     ] No close match found for 'keras' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.850010 [info     ] No close match found for 'scikit-learn' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.850329 [info     ] No close match found for 'hadoop' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.850554 [info     ] No close match found for 'spark' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.850803 [info     ] No close match found for 'tableau' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.851068 [info     ] No close match found for 'matplotlib' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.851347 [info     ] No close match found for 'achievement' in category 'classes' [OntologyAdapter]
#
# 2026-01-23T12:16:28.851672 [info     ] No close match found for 'implemented deep learning algorithms that improved prediction accuracy by 25%' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.851968 [info     ] No close match found for 'led a team in developing machine learning models for natural language processing applications' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.852279 [info     ] No close match found for 'collaborated with cross-functional teams to integrate models into cloud-based platforms' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.852537 [info     ] No close match found for 'developed predictive models for customer segmentation and churn analysis' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:28.853154 [info     ] No close match found for 'analyzed large datasets using hadoop and spark frameworks' in category 'individuals' [OntologyAdapter]
#
# 2026-01-23T12:16:29.939946 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:30.334948 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:30.649505 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:30.968075 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:16:31.281079 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:16:31.667881 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:16:32.675924 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:33.704506 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:34.061393 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:34.357683 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:34.661605 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:16:35.067365 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:16:35.385672 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:16:37.794069 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:39.666666 [info     ] Coroutine task started: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:40.170844 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:45.612482 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:45.927914 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:46.239701 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:46.627807 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:16:46.939876 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:16:47.271638 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:16:47.670441 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:50.725921 [info     ] Coroutine task started: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:51.498000 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:51.893986 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:16:52.214571 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:16:52.662056 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:16:53.194561 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:16:53.527277 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]
#
# 2026-01-23T12:16:59.161163 [info     ] Coroutine task completed: `add_data_points` [run_tasks_base]
#
# 2026-01-23T12:16:59.479136 [info     ] Coroutine task completed: `summarize_text` [run_tasks_base]
#
# 2026-01-23T12:17:00.018731 [info     ] Coroutine task completed: `extract_graph_from_data` [run_tasks_base]
#
# 2026-01-23T12:17:00.342833 [info     ] Async Generator task completed: `extract_chunks_from_documents` [run_tasks_base]
#
# 2026-01-23T12:17:00.738792 [info     ] Coroutine task completed: `classify_documents` [run_tasks_base]
#
# 2026-01-23T12:17:01.278396 [info     ] Pipeline run completed: `77708808-5b06-5f2d-ab9e-779ba4f9df55` [run_tasks_with_telemetry()]

# %%
import pathlib
from cognee.api.v1.visualize import visualize_graph

# Use the current working directory instead of __file__:
notebook_dir = pathlib.Path.cwd()

graph_file_path = (notebook_dir / ".artifacts" / "graph_visualization.html").resolve()

# Make sure to convert to string if visualize_graph expects a string
b = await visualize_graph(str(graph_file_path))
# Out:
# 2026-01-23T12:17:02.355578 [info     ] Retrieved 157 nodes and 412 edges in 0.01 seconds [cognee.shared.logging_utils]
#
# 2026-01-23T12:17:02.825256 [info     ] Graph visualization saved as /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/Memory_handler/.artifacts/graph_visualization.html [cognee.shared.logging_utils]
#
# 2026-01-23T12:17:02.826693 [info     ] The HTML file has been stored at path: /Users/jpv/Bharath_J_P_V/Learning/Gen_ai/Memory_handler/.artifacts/graph_visualization.html [cognee.shared.logging_utils]

# %%
async def search(
    vector_engine,
    collection_name: str,
    query_text: str = None,
):
    query_vector = (await vector_engine.embedding_engine.embed_text([query_text]))[0]

    connection = await vector_engine.get_connection()
    collection = await connection.open_table(collection_name)

    results = await collection.vector_search(query_vector).limit(10).to_pandas()

    result_values = list(results.to_dict("index").values())

    return [
        dict(
            id=str(result["id"]),
            payload=result["payload"],
            score=result["_distance"],
        )
        for result in result_values
    ]


from cognee.infrastructure.databases.vector import get_vector_engine

vector_engine = get_vector_engine()
results = await search(vector_engine, "Entity_name", "sarah.nguyen@example.com")
for result in results:
    print(result)
# Out:
# {'id': '4d8dda57-2681-5264-a2bd-e2ddfe66a785', 'payload': {'id': '4d8dda57-2681-5264-a2bd-e2ddfe66a785', 'created_at': 1769170600522, 'updated_at': 1769170600522, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'sarah nguyen'}, 'score': 0.5709534883499146}
# {'id': 'b6365021-70ae-53ea-83e7-885714b56092', 'payload': {'id': 'b6365021-70ae-53ea-83e7-885714b56092', 'created_at': 1769170583867, 'updated_at': 1769170583867, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'jessica.miller@example.com'}, 'score': 0.7203113436698914}
# {'id': 'ca14dbae-558b-5284-b057-dc2b1e965693', 'payload': {'id': 'ca14dbae-558b-5284-b057-dc2b1e965693', 'created_at': 1769170608033, 'updated_at': 1769170608033, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'michael.rodriguez@example.com'}, 'score': 0.7379818558692932}
# {'id': '282e7e92-e3d5-5a27-96fd-f145d6ebf7ec', 'payload': {'id': '282e7e92-e3d5-5a27-96fd-f145d6ebf7ec', 'created_at': 1769170584809, 'updated_at': 1769170584809, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'david.thompson@example.com'}, 'score': 0.7757569551467896}
# {'id': '5066c251-53a3-5f4c-a650-f291057b4659', 'payload': {'id': '5066c251-53a3-5f4c-a650-f291057b4659', 'created_at': 1769170583867, 'updated_at': 1769170583867, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'salesforce'}, 'score': 1.3354233503341675}
# {'id': 'd510e7a8-85a6-557e-be89-3bef491c190f', 'payload': {'id': 'd510e7a8-85a6-557e-be89-3bef491c190f', 'created_at': 1769170588921, 'updated_at': 1769170588921, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'san francisco, ca'}, 'score': 1.3495469093322754}
# {'id': '6b726763-e259-5e91-b505-85284f8ea5ea', 'payload': {'id': '6b726763-e259-5e91-b505-85284f8ea5ea', 'created_at': 1769170600522, 'updated_at': 1769170600522, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'sas'}, 'score': 1.378708004951477}
# {'id': '1bc9f2ec-8dcd-5cf7-b254-50d85647b8c7', 'payload': {'id': '1bc9f2ec-8dcd-5cf7-b254-50d85647b8c7', 'created_at': 1769170584809, 'updated_at': 1769170584809, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '(555) 456-7890'}, 'score': 1.3842216730117798}
# {'id': 'e13e72c7-0fc9-575e-800c-7739b4050624', 'payload': {'id': 'e13e72c7-0fc9-575e-800c-7739b4050624', 'created_at': 1769170608033, 'updated_at': 1769170608033, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '(555) 234-5678'}, 'score': 1.3903616666793823}
# {'id': '435dbd37-ab20-503c-9e99-ab8b8a3484e5', 'payload': {'id': '435dbd37-ab20-503c-9e99-ab8b8a3484e5', 'created_at': 1769170613935, 'updated_at': 1769170613935, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'senior data scientist'}, 'score': 1.3935251235961914}

# %%
from cognee.api.v1.search import SearchType

node = (await vector_engine.search("Entity_name", "sarah.nguyen@example.com"))[0]
node_name = node.payload["text"]

search_results = await cognee.search(query_type=SearchType.SUMMARIES, query_text=node_name)
print("\n\Extracted summaries are:\n")
for result in search_results:
    print(f"{result}\n")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\E'
# /var/folders/rw/4k88jv4x315d2kjjqyn8hhgc0000gn/T/ipykernel_22820/3327559834.py:7: SyntaxWarning: invalid escape sequence '\E'
#   print("\n\Extracted summaries are:\n")
#
# 2026-01-23T12:27:14.208665 [info     ] Starting summary retrieval for query: 'sarah nguyen' [SummariesRetriever]
#
# 2026-01-23T12:27:15.120356 [info     ] Found 6 summaries from vector search [SummariesRetriever]
#
# 2026-01-23T12:27:15.120976 [info     ] Returning 6 summary payloads   [SummariesRetriever]
#
# 2026-01-23T12:27:15.121498 [info     ] Starting completion generation for query: 'sarah nguyen' [SummariesRetriever]
#
# 2026-01-23T12:27:15.122084 [info     ] Returning context with 6 item(s) [SummariesRetriever]
# \Extracted summaries are:
#
# {'id': 'ea178f20-a297-5401-9ef5-7f55a2d06245', 'created_at': 1769170613935, 'updated_at': 1769170613935, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Senior Data Scientist with 8+ years’ experience in machine learning and predictive analytics; Ph.D. in Computer Science (Stanford). Specializes in NLP, deep learning, and deploying scalable production models. Proficient in Python, R, SQL, TensorFlow, Keras, Scikit‑Learn, Hadoop and Spark.'}
#
# {'id': 'c2fc420d-f56a-50f7-9029-9d0df736e7d1', 'created_at': 1769170608032, 'updated_at': 1769170608032, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Data Scientist with expertise in machine learning and statistical modeling, experienced in handling large datasets and turning data into actionable business outcomes; notable achievement: cut customer acquisition cost by 15%.'}
#
# {'id': '82dbd9c6-9fcd-5dc5-a533-16bc8bf9c07c', 'created_at': 1769170583867, 'updated_at': 1769170583867, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Seasoned Sales Manager with a proven record of driving revenue growth and leading high-performing teams; BA in Business Administration (USC).'}
#
# {'id': 'b01b7968-860e-5c2f-bade-3a4ea57d1be8', 'created_at': 1769170584809, 'updated_at': 1769170584809, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': "Creative Graphic Designer with 8+ years' experience in visual design and branding. Adept with Adobe Creative Suite and basic web design (HTML/CSS); B.F.A. in Graphic Design from RISD."}
#
# {'id': '72d2b1b1-3db9-53a9-8920-45e89edada82', 'created_at': 1769170600522, 'updated_at': 1769170600522, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Data Scientist with 6 years of machine learning experience, focused on predictive modeling and algorithm optimization for financial and supply-chain applications. Skilled in Python, R, PyTorch, scikit-learn, and cloud platforms (AWS, Azure).'}
#
# {'id': '4f305c65-2a89-52c3-ab9c-5c7876c32447', 'created_at': 1769170588921, 'updated_at': 1769170588921, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'TechNova Solutions (San Francisco, CA) is hiring a Senior Data Scientist — Machine Learning to design, build, and productionize advanced ML models, analyze large-scale datasets, and translate findings into product features. The role includes cross-functional collaboration, staying current with ML research, and mentoring junior team members.'}

# %%
from cognee.api.v1.search import SearchType

node = (await vector_engine.search("Entity_name", "sarah.nguyen@example.com"))[0]
node_name = node.payload["text"]

search_results = await cognee.search(query_type=SearchType.SUMMARIES, query_text=node_name)
print("Extracted summaries are:\n")
for result in search_results:
    print(f"{result}\n")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\E'
# /var/folders/rw/4k88jv4x315d2kjjqyn8hhgc0000gn/T/ipykernel_22820/3327559834.py:7: SyntaxWarning: invalid escape sequence '\E'
#   print("\n\Extracted summaries are:\n")
#
# 2026-01-23T12:32:02.666255 [info     ] Starting summary retrieval for query: 'sarah nguyen' [SummariesRetriever]
#
# 2026-01-23T12:32:03.693489 [info     ] Found 6 summaries from vector search [SummariesRetriever]
#
# 2026-01-23T12:32:03.694260 [info     ] Returning 6 summary payloads   [SummariesRetriever]
#
# 2026-01-23T12:32:03.694771 [info     ] Starting completion generation for query: 'sarah nguyen' [SummariesRetriever]
#
# 2026-01-23T12:32:03.695227 [info     ] Returning context with 6 item(s) [SummariesRetriever]
# \Extracted summaries are:
#
# {'id': 'ea178f20-a297-5401-9ef5-7f55a2d06245', 'created_at': 1769170613935, 'updated_at': 1769170613935, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Senior Data Scientist with 8+ years’ experience in machine learning and predictive analytics; Ph.D. in Computer Science (Stanford). Specializes in NLP, deep learning, and deploying scalable production models. Proficient in Python, R, SQL, TensorFlow, Keras, Scikit‑Learn, Hadoop and Spark.'}
#
# {'id': 'c2fc420d-f56a-50f7-9029-9d0df736e7d1', 'created_at': 1769170608032, 'updated_at': 1769170608032, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Data Scientist with expertise in machine learning and statistical modeling, experienced in handling large datasets and turning data into actionable business outcomes; notable achievement: cut customer acquisition cost by 15%.'}
#
# {'id': '82dbd9c6-9fcd-5dc5-a533-16bc8bf9c07c', 'created_at': 1769170583867, 'updated_at': 1769170583867, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Seasoned Sales Manager with a proven record of driving revenue growth and leading high-performing teams; BA in Business Administration (USC).'}
#
# {'id': 'b01b7968-860e-5c2f-bade-3a4ea57d1be8', 'created_at': 1769170584809, 'updated_at': 1769170584809, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': "Creative Graphic Designer with 8+ years' experience in visual design and branding. Adept with Adobe Creative Suite and basic web design (HTML/CSS); B.F.A. in Graphic Design from RISD."}
#
# {'id': '72d2b1b1-3db9-53a9-8920-45e89edada82', 'created_at': 1769170600522, 'updated_at': 1769170600522, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Data Scientist with 6 years of machine learning experience, focused on predictive modeling and algorithm optimization for financial and supply-chain applications. Skilled in Python, R, PyTorch, scikit-learn, and cloud platforms (AWS, Azure).'}
#
# {'id': '4f305c65-2a89-52c3-ab9c-5c7876c32447', 'created_at': 1769170588921, 'updated_at': 1769170588921, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'TechNova Solutions (San Francisco, CA) is hiring a Senior Data Scientist — Machine Learning to design, build, and productionize advanced ML models, analyze large-scale datasets, and translate findings into product features. The role includes cross-functional collaboration, staying current with ML research, and mentoring junior team members.'}

# %%
search_results = await cognee.search(query_type=SearchType.CHUNKS, query_text=node_name)
print("\n\nExtracted chunks are:\n")
for result in search_results:
    print(f"{result}\n")
# Out:
# 2026-01-23T12:33:03.913573 [info     ] Starting chunk retrieval for query: 'sarah nguyen' [ChunksRetriever]
#
# 2026-01-23T12:33:04.806392 [info     ] Found 6 chunks from vector search [ChunksRetriever]
#
# 2026-01-23T12:33:04.807081 [info     ] Returning 6 chunk payloads     [ChunksRetriever]
#
# 2026-01-23T12:33:04.807565 [info     ] Starting completion generation for query: 'sarah nguyen' [ChunksRetriever]
#
# 2026-01-23T12:33:04.808244 [info     ] Returning context with 6 item(s) [ChunksRetriever]
# Extracted chunks are:
#
# {'id': '74ce30f5-feb6-54e7-ae82-bb737740b009', 'created_at': 1769170600522, 'updated_at': 1769170600522, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '\nCV 3: Relevant\nName: Sarah Nguyen\nContact Information:\n\nEmail: sarah.nguyen@example.com\nPhone: (555) 345-6789\nSummary:\n\nData Scientist specializing in machine learning with 6 years of experience. Passionate about leveraging data to drive business solutions and improve product performance.\n\nEducation:\n\nM.S. in Statistics, University of Washington (2014)\nB.S. in Applied Mathematics, University of Texas at Austin (2012)\nExperience:\n\nData Scientist, QuantumTech (2016 – Present)\nDesigned and implemented machine learning algorithms for financial forecasting.\nImproved model efficiency by 20% through algorithm optimization.\nJunior Data Scientist, DataCore Solutions (2014 – 2016)\nAssisted in developing predictive models for supply chain optimization.\nConducted data cleaning and preprocessing on large datasets.\nSkills:\n\nProgramming Languages: Python, R\nMachine Learning Frameworks: PyTorch, Scikit-Learn\nStatistical Analysis: SAS, SPSS\nCloud Platforms: AWS, Azure\n'}
#
# {'id': 'e5f94a5c-68a4-5542-8b5b-be90253cc22f', 'created_at': 1769170583867, 'updated_at': 1769170583867, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': "\nCV 5: Not Relevant\nName: Jessica Miller\nContact Information:\n\nEmail: jessica.miller@example.com\nPhone: (555) 567-8901\nSummary:\n\nExperienced Sales Manager with a strong track record in driving sales growth and building high-performing teams. Excellent communication and leadership skills.\n\nEducation:\n\nB.A. in Business Administration, University of Southern California (2010)\nExperience:\n\nSales Manager, Global Enterprises (2015 – Present)\nManaged a sales team of 15 members, achieving a 20% increase in annual revenue.\nDeveloped sales strategies that expanded customer base by 25%.\nSales Representative, Market Leaders Inc. (2010 – 2015)\nConsistently exceeded sales targets and received the 'Top Salesperson' award in 2013.\nSkills:\n\nSales Strategy and Planning\nTeam Leadership and Development\nCRM Software: Salesforce, Zoho\nNegotiation and Relationship Building\n"}
#
# {'id': '10ccae27-2f83-5624-8288-844c3f69eba1', 'created_at': 1769170584809, 'updated_at': 1769170584809, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '\nCV 4: Not Relevant\nName: David Thompson\nContact Information:\n\nEmail: david.thompson@example.com\nPhone: (555) 456-7890\nSummary:\n\nCreative Graphic Designer with over 8 years of experience in visual design and branding. Proficient in Adobe Creative Suite and passionate about creating compelling visuals.\n\nEducation:\n\nB.F.A. in Graphic Design, Rhode Island School of Design (2012)\nExperience:\n\nSenior Graphic Designer, CreativeWorks Agency (2015 – Present)\nLed design projects for clients in various industries.\nCreated branding materials that increased client engagement by 30%.\nGraphic Designer, Visual Innovations (2012 – 2015)\nDesigned marketing collateral, including brochures, logos, and websites.\nCollaborated with the marketing team to develop cohesive brand strategies.\nSkills:\n\nDesign Software: Adobe Photoshop, Illustrator, InDesign\nWeb Design: HTML, CSS\nSpecialties: Branding and Identity, Typography\n'}
#
# {'id': '483ec38a-30fc-5aa2-99f7-5290f5eb0c8b', 'created_at': 1769170613935, 'updated_at': 1769170613935, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '\nCV 1: Relevant\nName: Dr. Emily Carter\nContact Information:\n\nEmail: emily.carter@example.com\nPhone: (555) 123-4567\nSummary:\n\nSenior Data Scientist with over 8 years of experience in machine learning and predictive analytics. Expertise in developing advanced algorithms and deploying scalable models in production environments.\n\nEducation:\n\nPh.D. in Computer Science, Stanford University (2014)\nB.S. in Mathematics, University of California, Berkeley (2010)\nExperience:\n\nSenior Data Scientist, InnovateAI Labs (2016 – Present)\nLed a team in developing machine learning models for natural language processing applications.\nImplemented deep learning algorithms that improved prediction accuracy by 25%.\nCollaborated with cross-functional teams to integrate models into cloud-based platforms.\nData Scientist, DataWave Analytics (2014 – 2016)\nDeveloped predictive models for customer segmentation and churn analysis.\nAnalyzed large datasets using Hadoop and Spark frameworks.\nSkills:\n\nProgramming Languages: Python, R, SQL\nMachine Learning: TensorFlow, Keras, Scikit-Learn\nBig Data Technologies: Hadoop, Spark\nData Visualization: Tableau, Matplotlib\n'}
#
# {'id': '26124ff5-b156-52d4-8033-aaeaaed0e744', 'created_at': 1769170608032, 'updated_at': 1769170608032, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': '\nCV 2: Relevant\nName: Michael Rodriguez\nContact Information:\n\nEmail: michael.rodriguez@example.com\nPhone: (555) 234-5678\nSummary:\n\nData Scientist with a strong background in machine learning and statistical modeling. Skilled in handling large datasets and translating data into actionable business insights.\n\nEducation:\n\nM.S. in Data Science, Carnegie Mellon University (2013)\nB.S. in Computer Science, University of Michigan (2011)\nExperience:\n\nSenior Data Scientist, Alpha Analytics (2017 – Present)\nDeveloped machine learning models to optimize marketing strategies.\nReduced customer acquisition cost by 15% through predictive modeling.\nData Scientist, TechInsights (2013 – 2017)\nAnalyzed user behavior data to improve product features.\nImplemented A/B testing frameworks to evaluate product changes.\nSkills:\n\nProgramming Languages: Python, Java, SQL\nMachine Learning: Scikit-Learn, XGBoost\nData Visualization: Seaborn, Plotly\nDatabases: MySQL, MongoDB\n'}
#
# {'id': '05701f79-147e-5f85-92fd-30e3ea1ac4ec', 'created_at': 1769170588921, 'updated_at': 1769170588921, 'ontology_valid': False, 'version': 1, 'topological_rank': 0, 'type': 'IndexSchema', 'text': 'Senior Data Scientist (Machine Learning)\n\nCompany: TechNova Solutions\nLocation: San Francisco, CA\n\nJob Description:\n\nTechNova Solutions is seeking a Senior Data Scientist specializing in Machine Learning to join our dynamic analytics team. The ideal candidate will have a strong background in developing and deploying machine learning models, working with large datasets, and translating complex data into actionable insights.\n\nResponsibilities:\n\nDevelop and implement advanced machine learning algorithms and models.\nAnalyze large, complex datasets to extract meaningful patterns and insights.\nCollaborate with cross-functional teams to integrate predictive models into products.\nStay updated with the latest advancements in machine learning and data science.\nMentor junior data scientists and provide technical guidance.\nQualifications:\n\nMaster’s or Ph.D. in Data Science, Computer Science, Statistics, or a related field.\n5+ years of experience in data science and machine learning.\nProficient in Python, R, and SQL.\nExperience with deep learning frameworks (e.g., TensorFlow, PyTorch).\nStrong problem-solving skills and attention to detail.\nCandidate CVs\n'}

# %%
search_results = await cognee.search(query_type=SearchType.GRAPH_COMPLETION, query_text=node_name)
print("\n\nExtracted sentences are:\n")
for result in search_results:
    print(f"{result}\n")
# Out:
# 2026-01-23T12:33:14.519174 [info     ] Vector collection retrieval completed: Retrieved distances from 6 collections in 0.19s [cognee.shared.logging_utils]
#
# 2026-01-23T12:33:14.520038 [info     ] Retrieving ID-filtered graph from database. [CogneeGraph]
#
# 2026-01-23T12:33:14.536953 [info     ] ID-filtered retrieval: 157 nodes and 412 edges in 0.02s [cognee.shared.logging_utils]
#
# 2026-01-23T12:33:14.539894 [info     ] Graph projection completed: 157 nodes, 412 edges in 0.00s [CogneeGraph]
# Extracted sentences are:
#
# Sarah Nguyen — Data Scientist (machine learning), 6 years’ experience. Email: sarah.nguyen@example.com, Phone: (555) 345-6789. Education: M.S. in Statistics (Univ. of Washington, 2014); B.S. in Applied Mathematics (Univ. of Texas at Austin, 2012). Current: Data Scientist at QuantumTech (since 2016) — designed ML algorithms for financial forecasting, improved model efficiency by 20%. Skills: Python, R, PyTorch, Scikit‑Learn, SAS, SPSS, AWS, Azure.
